# %%
import pandas as pd

# %%
# Sloooow
# df = pd.read_csv('data/train.csv')

df = pd.read_csv('data/train.chunk.csv')
df
# Out:
#                                                    title label_quality  \
# 0      Hidrolavadora Lavor One 120 Bar 1700w  Bomba A...    unreliable
# 1                      Placa De Sonido - Behringer Umc22    unreliable
# 2                   Maquina De Lavar Electrolux 12 Kilos    unreliable
# 3      Par Disco De Freio Diant Vent Gol 8v 08/ Frema...    unreliable
# 4      Flashes Led Pestañas Luminoso Falso Pestañas P...    unreliable
# ...                                                  ...           ...
# 99994  Bateria Sony Np-55 Ccdtr550 Ccd-tr550 Ccdtr55e...    unreliable
# 99995  Maquina De Coser Gemsy Doble Arrastre Industri...    unreliable
# 99996  Video Cassete Samsung Vm-1260 Bi-volt Funciona...    unreliable
# 99997                    Camisa Rogério Ceni  - Mito 618    unreliable
# 99998                                             983007    unreliable
#
#          language                   category
# 0         spanish  ELECTRIC_PRESSURE_WASHERS
# ...

# %%
df.groupby(['language', 'label_quality']).count()
# Out:
#                           title  category
# language   label_quality
# portuguese reliable        3529      3529
#            unreliable     46428     46428
# spanish    reliable        2496      2496
#            unreliable     47546     47546

# %%
for i in range(500): 
    print(df.ix[i]['title'])
# Out:
# Hidrolavadora Lavor One 120 Bar 1700w  Bomba Aluminio Italia
# Placa De Sonido - Behringer Umc22
# Maquina De Lavar Electrolux 12 Kilos
# Par Disco De Freio Diant Vent Gol 8v 08/ Fremax Bd5298
# Flashes Led Pestañas Luminoso Falso Pestañas Para Partido
# 4 Microaspersor Irrigação Ultra 7,20 Metros
# Raquete Clash 100 Tour - Nova
# Kit Tripe Para Celular Ou Câmera Fotog 1,20m + Brinde + Nf-e
# Filtro Ar Bonanza 1984/1990 Sar3589
# Gatito Lunchera Neoprene
# Condensador Bosch Vw Fusca 1.300 De 1968 À 1974
# Rosario Contador De Billetes Uv / Mg Detecta Falsos Nuevo
# Banhos Mágicos
# Caixa Setor Hidraulica Ford Focus 2.0 2006
# Tupia Coluna Laminadora P/ Fresa 6-8mm 1250w Mdf Acm Sh 220v
# Touca Porco Com Cachecol E Luva
# Projeto Unidade Hidraulica 3000 Psi
# Maleta Para Guardar E Transportar Medicamentos - Promoção
# Battery Pack Huawei 13000mah Cuerpo De Metal 2 Puertos Usb
# Capa De Cilindro Tecido Painel De Festa Sereia -  3 Peças
# ...

# %%
# Process records
# - homogeineizar (todo minusculas, limpiar caracteres raros, errores de ortografia, quitar acentos etc)
# - limpiar stopwords
# -

# %%
# Features suggested:
# - has_year
# - has_measure: lt kg cm g v hz watts
# - has_surface: [cms]X[cms] [cms]X[mts] nXn[mm/cms] 250×365 
# - has_volume: 100x40x40 
# - has_model: Sbr5001 Bc558 D-l17 K24 Ce30p2 B-763xs Spa502g 
# - has_brand: Audi Garmin Fiat Honda Philips Zara Braun Amarok
# - has_category_in_title
# - is_reliable: 1/0
# -

# %%
# Training model

# %%
# Pickle model
